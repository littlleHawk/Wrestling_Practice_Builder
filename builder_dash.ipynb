# %% [markdown]
# # Build Program Dashboard

# %% [markdown]
# ### Initialize Libraries and Dependancies

# %%
import widgets_utilites as w
import ipywidgets as widgets
import Practice_Builder as pb
# Out:
# MOVES IN LIST
# ---------------------------------------------------
#          move  est_time           category priority
# 0  double_leg        20           takedown   medium
# 1     standup        20            standup     high
# 2      switch        10           reversal   medium
# 3  single_leg        25           takedown     high
# 4    snapdown        10           takedown     high
# 5      sprawl         5   takedown_defense     high

# %% [markdown]
# Call Dash

# %%
row1 = widgets.HBox([w.team_level, w.intensity_slider])
row2 = widgets.HBox([w.practice_time, w.padding])
row3 = widgets.HBox([w.warmup_time, w.cooldown_time, w.live])
row4 = widgets.HBox([w.water_break, w.move_choice])

dash = widgets.VBox([
    widgets.HTML("<h2>Wrestling Practice Builder</h2>"),
    widgets.HBox([w.practice_title]),
    widgets.Label("Step 1: Select Team Level"),
    row1,
    widgets.Label("Step 2: Timing"),
    row2,
    row3,
    widgets.Label("Step 3: Select Moves"),
    row4,
    widgets.HTML("<br>"),
    w.generate_button,
    widgets.HTML("<hr>"),

    pb.output_window
])

display(dash)

# %%
# save final generated practice to text file
def on_button_clicked(b):
    pb.output_window.clear_output()
